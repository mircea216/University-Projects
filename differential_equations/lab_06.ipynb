# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
C1,C2=var('C1,C2')
sol=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> 1/2*(C1 + 2*C2)*e^(3*t) + 1/2*(C1 - 2*C2)*e^(-t)

# %%
sol_y(t,C1,C2)=sol[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> 1/4*(C1 + 2*C2)*e^(3*t) - 1/4*(C1 - 2*C2)*e^(-t)

# %%
plot(sol_x(t,1,1),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t,1,1),t,1,4,color='green')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==2*x-y
deq2=diff(y,t)==x+2*y
syst=[deq1,deq2]
C1,C2=var('C1,C2')
sol1=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol1[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> (C1*cos(t) - C2*sin(t))*e^(2*t)

# %%
sol_y(t,C1,C2)=sol1[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> (C2*cos(t) + C1*sin(t))*e^(2*t)

# %%
plot(sol_x(t,1,1),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t,1,1),t,-4,4,color='green')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
z=function('z')(t)
deq1=diff(x,t)==x-y+z
deq2=diff(y,t)==x+y-z
deq3=diff(z,t)==-y+2*z
syst=[deq1,deq2,deq3]
C1,C2,C3=var('C1,C2,C3')
sol2=desolve_system(syst, [x,y,z],[0,C1,C2,C3])
sol_x(t,C1,C2,C3)=sol2[0].rhs()
sol_x
# Out:
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (2*C1 + C2 - 2*C3)*e^t

# %%
sol_y(t,C1,C2,C3)=sol2[1].rhs()
sol_y
# Out:
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t + C2*e^t

# %%
sol_z(t,C1,C2,C3)=sol2[2].rhs()
sol_z
# Out:
# (t, C1, C2, C3) |--> C1*t*e^t - C3*t*e^t - (C1 + C2 - 2*C3)*e^(2*t) + (C1 + C2 - C3)*e^t

# %%
plot(sol_x(t,1,1,1),t,-4,4,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_y(t,1,-1,0),t,-2,4,color='blue')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(sol_z(t,1,-1,0),t,-2,4,color='green')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x+4*y
deq2=diff(y,t)==x+y
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,1,2]
sola=desolve_system(syst, vars,in_cond)
sol_x(t)=sola[0].rhs()
sol_x
# Out:
# t |--> 5/2*e^(3*t) - 3/2*e^(-t)

# %%
sol_y(t)=sola[1].rhs()
sol_y
# Out:
# t |--> 5/4*e^(3*t) + 3/4*e^(-t)

# %%
g1=plot(sol_x(t),t,1,4,color='red')
g2=plot(sol_y(t),t,1,4,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x - y + t - 1
deq2=diff(y,t)== -2*x + 4*y + cos(t)
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,1,2]
solb=desolve_system(syst, vars,in_cond)
sol_x(t)=solb[0].rhs()
sol_x
# Out:
# t |--> -1/221*(235*sqrt(17)*sinh(1/2*sqrt(17)*t) - 782*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - 2*t - 1/26*cos(t) + 5/26*sin(t) - 5/2

# %%
sol_y(t)=solb[1].rhs()
sol_y
# Out:
# t |--> -1/442*(77*sqrt(17)*sinh(1/2*sqrt(17)*t) - 1649*cosh(1/2*sqrt(17)*t))*e^(5/2*t) - t - 3/13*cos(t) + 2/13*sin(t) - 3/2

# %%
g1=plot(sol_x(t),t,1,4,color='red')
g2=plot(sol_y(t),t,1,4,color='blue')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==x + 2*y + e^(-t)
deq2=diff(y,t)== -2*x + y + 1
syst=[deq1,deq2]
vars=[x,y]
in_cond=[0,0,1]
solc=desolve_system(syst, vars, in_cond)
sol_x(t)=solc[0].rhs()
sol_x
# Out:
# t |--> -1/20*(3*cos(2*t) - 29*sin(2*t))*e^t - 1/4*e^(-t) + 2/5

# %%
sol_y(t)=solc[1].rhs()
sol_y
# Out:
# t |--> 1/20*(29*cos(2*t) + 3*sin(2*t))*e^t - 1/4*e^(-t) - 1/5

# %%
g1=plot(sol_x(t),t,0,4,color='red')
g2=plot(sol_y(t),t,0,4,color='green')
show(g1+g2)
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==y
deq2=diff(y,t)==-x-2*y
syst=[deq1,deq2]
C1,C2=var('C1,C2')
sol3=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol3[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> C1*t*e^(-t) + C2*t*e^(-t) + C1*e^(-t)

# %%
sol_y(t,C1,C2)=sol3[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> -C1*t*e^(-t) - C2*t*e^(-t) + C2*e^(-t)

# %%
f1(u,v)=v
f2(u,v)=-u-2*v
plot_vector_field( [f1(u,v),f2(u,v)], [u,-10,10], [v,-10,10] )
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
limit(sol_x(t), t=infinity)
# Out:
# 0

# %%
limit(sol_y(t), t=infinity)
# Out:
# 0

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==2*x+y
deq2=diff(y,t)==x+2*y
syst=[deq1,deq2]
C1,C2=var('C1,C2')
sol4a=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol4a[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> 1/2*(C1 + C2)*e^(3*t) + 1/2*(C1 - C2)*e^t

# %%
sol_y(t,C1,C2)=sol4a[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> 1/2*(C1 + C2)*e^(3*t) - 1/2*(C1 - C2)*e^t

# %%
f1(u,v)=2*u+v
f2(u,v)=u+2*v
plot_vector_field( [f1(u,v),f2(u,v)], [u,-10,10], [v,-10,10] )
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t = var('t')
x=function('x')(t)
y=function('y')(t)
deq1=diff(x,t)==y
deq2=diff(y,t)==-x
syst=[deq1,deq2]
C1,C2=var('C1,C2')
sol4b=desolve_system(syst, [x,y],[0,C1,C2])
sol_x(t,C1,C2)=sol4b[0].rhs()
sol_x
# Out:
# (t, C1, C2) |--> C1*cos(t) + C2*sin(t)

# %%
sol_y(t,C1,C2)=sol4b[1].rhs()
sol_y
# Out:
# (t, C1, C2) |--> C2*cos(t) - C1*sin(t)

# %%
f1(u,v)=v
f2(u,v)=-u
plot_vector_field( [f1(u,v),f2(u,v)], [u,-10,10], [v,-10,10] )
# Out:
# Graphics object consisting of 1 graphics primitive
