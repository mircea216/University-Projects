# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*y
sol=desolve(eqd,y)
# Out:
# _C*e^(2*x)

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*x*y
sol=desolve(eqd,y)
sol
# Out:
# _C*e^(x^2)

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*x*y
sol=desolve(eqd,y)
sol(1,x)
# Out:
# e^(x^2)

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*x*(1+y^2)
sol=desolve(eqd,y)
sol
# Out:
# 1/2*arctan(y(x)) == 1/2*x^2 + _C

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*x*(1+y^2)
sol=desolve(eqd,y)
sol(0,x)
# Out:
# 1/2*arctan(y(x)) == 1/2*x^2

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*y
desolve(eqd,y,ics=[0,1])
# Out:
# e^(2*x)

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==1+y^2
desolve(eqd,y,ics=[0,1])
# Out:
# arctan(y(x)) == 1/4*pi + x

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==1/cos(x)-y*tan(x)
desolve(eqd,y,ics=[0,0])
# Out:
# tan(x)/sec(x)

# %%
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)==k*y
desolve(eqd,[y,x],ics=[0,1])
# Out:
# e^(k*x)

# %%
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)==x^3-k/x*y
desolve(eqd,[y,x])
# Out:
# (x^4*x^k/(k + 4) + _C)/x^k

# %%
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)==x^3-k/x*y
sol(x,k)=desolve(eqd,[y,x])
_C=var('_C')
sol.substitute(_C==1)
sol1(x,k)=sol.substitute(_C==1)
sol1(x,k)
plot(sol1(x,1),x,-10,10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)==x^3-k/x*y
sol(x,k)=desolve(eqd,[y,x],ics=[1,0])
sol(x,k)
plot(sol(x,1),x,-20,20)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,k=var('x,k')
y=function('y')(x)
eqd=diff(y,x)==x^3-k/x*y
sol(x,k)=desolve(eqd,[y,x],ics=[1,0])
sol(x,k)
plot([sol(x,1),sol(x,-1),sol(x,2),sol(x,3)],x,-50,50)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
x=var('x')
y=function('y')(x)
eqd1=diff(y,x)==cos(x)+y*(1/2)
desolve(eqd1,y)
# Out:
# -1/5*(2*(cos(x) - 2*sin(x))*e^(-1/2*x) - 5*_C)*e^(1/2*x)

# %%
x=var('x')
y=function('y')(x)
eqd2=diff(y,x)==cos(x)+y*(1/2)
sol2=desolve(eqd2,y)
_C=var('_C')
sol3=sol2.substitute(_C==1)
plot(sol3,x,-1,1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
# Out:
# diff(y(x), x) == cos(x) + 1/2*y(x)
