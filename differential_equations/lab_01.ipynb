# %%
1+2-3
# Out:
# 0

# %%
sin(pi/2)
# Out:
# 1

# %%
(1 + 2*(3 + 5^2))*sqrt(9)
# Out:
# 171

# %%
numerical_approx(44/13, digits=60)
# Out:
# 3.38461538461538461538461538461538461538461538461538461538462

# %%
x = SR.var('x')
p1=(x+1)^2
p1
# Out:
# (x + 1)^2

# %%
x=var('x')
eq1=x^4-3/2*x^3-x+3/2==0
solve(eq1,x)
# Out:
# [x == 1, x == (3/2), x == -1/2*I*sqrt(3) - 1/2, x == 1/2*I*sqrt(3) - 1/2]

# %%
limit(sin(x)/x,x=0)
# Out:
# 1

# %%
limit(cos(x)+1/x-pi,x=pi)
# Out:
# -pi + 1/pi - 1

# %%
x=SR.var('x')
y(x)=sqrt(1+x^4)
diff(y(x),x)
# Out:
# 2*x^3/sqrt(x^4 + 1)

# %%
x=var('x')
integrate(cos(x),x)
# Out:
# sin(x)

# %%
x=var('x')
I=3*x^3-2*x^2-5
integrate(I,x,0,1)
# Out:
# -59/12

# %%
x=var('x')
f(x)=x*sin(1/x)
plot(f(x),-3,3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
f(x)=e^(-x)-1
plot(f(x),-2,2,color='red')
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t=var('t')
x(t)=cos(t)
y(t)=sin(t)
parametric_plot((x(t), y(t)), (t, -pi/2, pi/2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t=var('t')
x(t)=(1-cos(t))*cos(t)
y(t)=(1-cos(t))*sin(t)
parametric_plot((x(t), y(t)), (t, 0, pi*2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t=var('t')
x(t)=sin(3*t)*cos(t)
y(t)=sin(3*t)*sin(t)
parametric_plot((x(t), y(t)), (t, 0, pi*2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y=var('x,y')
f(x,y)=x^2+y^2
implicit_plot(f(x,y)==1,(x,-1,1),(y,-1,1))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x,y=var('x,y')
f(x,y)=x^2-2*x*y-y^2
implicit_plot(f(x,y)==1,(x,-20,20),(y,-20,20))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
t=var('t')
x(t)=t-sin(t)
y(t)=1-cos(t)
parametric_plot((x(t),y(t)),(t, 0, pi*6))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x')
I=1/(x^2)
integrate(I,x,1,infinity)
# Out:
# 1

# %%
x,y=var('x,y')
syst=[2*x+y==3, x+3*y==-1]
solve(syst,x,y)
# Out:
# [[x == 2, y == -1]]

# %%
x=var('x')
y=function('y')(x)
eqd=diff(y,x)==2*y
desolve(eqd,y)
# Out:
# _C*e^(2*x)
